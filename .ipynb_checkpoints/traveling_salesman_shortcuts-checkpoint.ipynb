# %% [markdown]
# # Project

# %% [markdown]
# ## Overview
#
# In this project you will implement Kruskal's algorithm with path compression to find an approximation to the Traveling Salesman Problem.  You will be given a complete undirected graph with weights, and you will be expected to produce a minimum spanning tree along with a preorder traversal.

# %% [markdown]
# ## Installing Required Packages
#
# For this project we will be using several modules, some of which are not included in a standard installation of Python and/or Anaconda.
#
# For Linux and Mac users the following instructions can be performed in any shell of your choosing.  For Windows users the instructions are written for use in the `Anaconda Powershell Prompt (anaconda3)` application.
#
# We will use the conda package installer to help us acquire and install necessary packages.  One could also use pip the Python Package Installer, but the instructions below will only be given for conda.  A common error made by those new to anaconda and/or python is to install pacakges using the wrong pacakge manager, as there may be multiple versions of conda, python etc on their system.  Before installing the packages below be sure to first identify the correct conda (or pip).  For Linux and Mac we will assume that Anaconda was installed locally in your home directory and the bin directory is located at `~/opt/anaconda3/bin/` (Verify the location on your system in the event your installation/setup is different).  For Windows users we will assume you are using the `Anaconda Powershell Prompt (anaconda3)` application.  The instructions below assume that the correct conda can be found in your path, however you can always use the full or relative path for your system (e.g. `~/opt/anaconda3/bin/conda`).
#
# Install the following packages before attempting to complete project.
#
#
# ### Folium
#
# 1. `conda install -c conda-forge folium`
#
#
# ### BaseMap
#
#
# BaseMap may not be found in using pip, so we use conda.  This may take several attempts by conda, which is fine.  It will likely prompt you concerning the installation of a few dependencies (geos, proj4, ...) which should be installed.
#
# 1. `conda install basemap`
#
#
# ### OpenRouteService
#
# 1. `conda install -c nilsnolde openrouteservice`
#
# To use the OpenRouteService client interface you will need to acquire an API key.  Acquiring a key is optional as it requires you to sign up for a free account with [OpenRouteService](https://openrouteservice.org/dev/#/signup).  To get an API key do the following:
#
# 1. Sign up for an account at [OpenRouteService](https://openrouteservice.org/dev/#/signup).
#
# 1. Log in to your account, and click on Dashboard to take you to the 'Dev dashboard', be sure you are on the 'Tokens' tab of the Dev dashboard.
#
# 1. Find the section labeled 'Request a token' near the bottom of the page.
#
# 1. Click on 'Token type*' and select Free.
#
# 1. Click on 'Token name*' and enter a name for the token, e.g. 'Test Token'.
#
# 1. Click the button 'Create Token'.
#
# 1. On the Tokens tab of the Dev dashboard you should see a long string or seemingly random characters an numbers, this is your API key.  Click on the key to copy it to the clipboard.
#
# 1. Later in this notebook there is a code block containing `api_key=None`.  Replace `None` with a string containing your API key.

# %% [markdown]
# ## Imports

# %%
import numpy as np

# GIS Shapefile loader
import shapefile

# Map and map layers
import folium

# Driving and distance queries
from openrouteservice import client, convert, distance_matrix

# Plotting
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.animation
from IPython.display import HTML

# %% [markdown]
# ## Helper Functions

# %%
def distance(i,j, vertices):
    """
    Computes the distance between vertices[i] and vertices[j].
    i,j - Indices of nD points in vertices.
    vertices - An np.array containing nD points.
    Returns - The distance between the indexed points.
    """
    if i == j:
        return np.NaN
    d = np.array(vertices[i]) - np.array(vertices[j])
    return np.sqrt(d.dot(d))


def create_random_graph(cnt=10):
    """
    Creates a complete undirected graph containing `cnt` 2D random vertices.
    cnt - The number of 2D vertices to be randomly generated for the graph.
    Returns - (vertices, edges), where vertices is a np.array of 2D random
            points, and edges is a list of tuples (i,j,w) where i and j are
            indices into the vertex array, vertices, and w is the weight or
            2D distance between vertices[i] and vertices[j].
    """
    vertices = np.random.uniform(low=-10, high=10, size=(cnt,2))
    edges = [(i,j,distance(i,j,vertices)) 
         for i in range(cnt) 
         for j in range(i+1,cnt)]
    return (vertices, edges)


def plot_graph(vertices, edges, highlight_idx=None):
    """
    Plots the graph with edges.
    vertices - An np.array containing the 2D vertices of the graph.
    edges - A list of edge tuples (i,j,w) where i and j are indices into 
            vertices, and w is the weight of the edge connecting the 
            vertices, vertices[i] and vertices[j]. 
    """
    fig = plt.figure(figsize=(10, 8))

    plt.scatter(vertices[:,0], vertices[:,1], marker='D',color='blue', s=25)

    if edges is not None:
        for edge in edges:
            ev_x = [vertices[edge[0]][0], vertices[edge[1]][0]]
            ev_y = [vertices[edge[0]][1], vertices[edge[1]][1]]
            plt.plot(ev_x, ev_y, color='black', zorder=-1)
            
    if highlight_idx is not None:
        plt.scatter(vertices[highlight_idx,0], vertices[highlight_idx,1], marker='D',color='red', s=50)

    plt.show()


def naive_center(coords):
    """
    Computes a centroid of the passed 2D coordinates.
    coords - A list of 2D points.
    Returns - (a,b) where a and b are the mean of their respective coordinates.
    """
    return (np.mean([a[0] for a in coords]), np.mean([a[1] for a in coords]))


def in_bounding_box(center, bounds, point):
    """
    Returns True if point is inside or on the boundary of a box centered at 
    center with extents, bounds, and False otherwise.
    center - A 2D point representing the center of a axis-aligned box.
    bounds - The horizontal and vertical half-extents of the axis-aligned box.
    point - A 2D point to be tested against the box for containment.
    Returns - True if point is inside or on the boundary of a box centered at 
            center with extents, bounds, and False otherwise.
    """
    return ((center[0]-bounds[0]) <= point[0] <= (center[0]+bounds[0]) and 
            (center[1]-bounds[1]) <= point[1] <= (center[1]+bounds[1]))
    

def load_business_locations_by_class(shape_file, map_center, bound_box, landmark_class='BAR'):
    """
    Loads a shape file and returns all businesses whose landmark class matches the
    passed class.  Business locations that are outside of the passed region, 
    represented by map_center and bound_box, are culled from the returned list.
    shape_file - The path and file name of a shapefile containing fields as 
            described by https://data-cstx.opendata.arcgis.com/datasets/structures.
    map_center - The latitude and longitude of the center of the region of interest. 
    bound_box - The half-extents of a 'box' centered at map_center that defines the
            region of interest.  This box is used to cull business outside of the
            region.
    landmark_class - A string representing the class of the landmark to be returned
            by this function.  See the City of College Station GIS page for more 
            information.
    Returns - A list of dictionaries containing the occupant, name, building 
            footprint polygon, building location (center), and the shapefile record
            for the buisness.
    """
    reader = shapefile.Reader(shape_file)
    fields = reader.fields[1:]
    field_names = [field[0] for field in fields]

    location_data = []
    for sr in reader.shapeRecords():
        if landmark_class == sr.record[field_names.index('LANDMARK_C')]:
            rec = dict(zip(field_names, sr.record))
            geom = sr.shape.__geo_interface__
            poly = [(b,a) for a,b in geom['coordinates'][0]]
            cen = naive_center(poly)
            name = rec['OCCUPANT']
            if in_bounding_box(map_center, bound_box, cen):
                location_data.append(dict(name=name, geometry=poly, center=cen, record=rec))
    return location_data


def plot_location_data(location_data, map_center, graph=None, directions=None, draw_markers=False):
    """
    Plots a map centered at map_center.
    location_data - A list of dictionaries containing the occupant, name, building 
            footprint polygon, building location (center), and the shapefile record
            for the buisness.
    map_center - The latitude and longitude of the center of the region of interest. 
    graph - A tuple containing the vertices and edges of a graph.
    directions - A direction dictionary returned from OpenRouteService Client.directions.
    draw_markers - Flag.  If True a clickable marker will be drawn at each location
            containing the name and lat,long of the location.
    """
    m = folium.Map(location=map_center, zoom_start=14) 

    for location in location_data:
        folium.vector_layers.Polygon(location['geometry'],
                                     color='#0000FF',
                                     fill_color='#0000FF',
                                     fill_opacity=1,
                                     weight=3).add_to(m)
        if draw_markers:
            name = location['name']
            lat,lon = location['center']
            popup = "<strong>{0}</strong><br>Lat: {1:.3f}<br>Long: {2:.3f}".format(name, lat, lon)
            icon = folium.map.Icon(color='gray',
                                icon_color='white',
                                icon='beer', # fetches font-awesome.io symbols
                                prefix='fa')
            folium.map.Marker([lat, lon], icon=icon, popup=popup).add_to(m)

        if graph:
            vertex_list = graph[0]
            edge_list = graph[1]
            for edge in edge_list:
                line = [[vertex_list[edge[0]][1],vertex_list[edge[0]][0]],
                        [vertex_list[edge[1]][1],vertex_list[edge[1]][0]]]
                folium.PolyLine(line, color='red', weight=3).add_to(m)
        if directions:
            geometry = directions['routes'][0]['geometry']
            decoded_path = convert.decode_polyline(geometry)
            path_coords = [[p[1], p[0]] for p in decoded_path['coordinates']]
            folium.PolyLine(path_coords, color='green', weight=3).add_to(m)
            
    display(m)

        
def create_graph_from_business_locations(location_data, api_key=None):
    """
    Creates a complete undirected weighted graph from the passed location data.
    location_data - A list of dictionaries containing the occupant, name, building 
            footprint polygon, building location (center), and the shapefile record
            for the buisness.
    api_key - A user specific API key issued by OpenRouteService.  If None then 
            simple 2D straight line distances will be used in place of driving
            distance queries.  If a valid key is available then this function will
            query OpenRouteService for driving distances to weight each edge of
            the resulting graph.
    Returns - A graph whose vertices are business centers and a complete set of
            weighted edges.
    Note - Driving directions are not symmetric and so the distance in one 
            direction may differ in the opposite direction.  This function assumes
            these distances are symmetric and arbitrarily picks one of the two 
            distances for each edge in a consistent manner.  This is done because
            the graph returned is required to be undirected.    
    """
    
    if api_key is None:
        print('''
         ***********************************************************************
         No API Key was passed to this function.  This function will not be able
         query OpenRouteService for driving distances between business locations
         and will instead use the 2D distance function to compute weights.
         ***********************************************************************
              ''')
    
    map_vertices = [(location['center'][1],location['center'][0]) 
                    for location in location_data]
    
    if api_key:
        clnt = client.Client(key=api_key)

        request = {'locations': map_vertices,
                   'profile': 'driving-car',
                   'metrics': ['distance'],
                   'units': 'km',
                   'resolve_locations': True,
                   'dry_run': False}

        location_matrix = clnt.distance_matrix(**request)
        
        # edges - assume the distance matrix is symmetric 
        #       - even though this is not the case
        map_edges = [(i,j,location_matrix['distances'][i][j]) 
                     for i in range(len(map_vertices)) 
                     for j in range(i+1, len(map_vertices))]

    else:
        map_edges = [(i,j,distance(i,j,map_vertices)) 
                     for i in range(len(map_vertices)) 
                     for j in range(i+1,len(map_vertices))]
        
    return (map_vertices, map_edges)
        
    
def query_driving_directions(map_vertices, path, api_key=None):
    """
    Queries OpenRouteService for directions going through every point along the
    specified path.
    map_vertices - A list of vertices (locaitons)
    path - A list of indices of vertices (map_vertices) that give the set of
            waypoints, in order, that the driving directions must go through.            
    api_key - A user specific API key issued by OpenRouteService.  If None then 
            simple 2D straight line distances will be used in place of driving
            distance queries.  If a valid key is available then this function will
            query OpenRouteService for driving distances to weight each edge of
            the resulting graph.
    Returns - A directions dictionary.
    """
    if api_key is None:
        print('''
         ************************************************************************
         No API Key was passed to this function.   This function will not be able
         query OpenRouteService for driving directions between business locations
         and will return None.
         ************************************************************************
              ''')
        return None
    
    traversal_path = [map_vertices[idx] for idx in path]

    clnt = client.Client(key=api_key)
    directions = clnt.directions(traversal_path, profile='driving-car', preference='shortest')
    return directions

# %% [markdown]
# ## Kruskal's Algorithm
#
# The following pseudocode represents a high-level view of Kruskal's algorithm on a fully connected undirected weighted graph.
#
# <pre>
#   1. Create a forest of trees, where each vertex in the graph is the root of a tree.
#   2. Sort all edges in non-decreasing order, by weight.
#   3. While there are fewer than |V|-1 edges in the MST:
#   4.     Get the next edge from the sorted edges.
#   5.     If the edge connects two different trees:
#   6.         Add the edge to the MST.
#   7.     Else:
#   8.         Discard the edge.
# </pre>
#
# The goal of the algorithm is to merge the forest of trees using the smallest weight edges in a greedy fashion such that no cycles are introduced and the resulting tree spans the entire set of vertices with minimum total weight.  To do this the algorithm uses a disjoint-set data structure, which keeps track of the vertices of the graph partitioned into disjoint subsets (the forest of trees).
#
# Initially, all vertices begin in their own tree (Line 1), that is to say we partition the set of vertices into $|V|$ disjoint subsets.  Line 2 ensures that we try each edge from small to large.  The while loop on Line 3 needs only continue until there are exactly |V|-1 edges, because we know that the MST will contain exactly that number of edges.  To process lines 5 through 8 above we will use the `Union-Find` algorithm with our disjoint-set data structure.  The `Union-Find` performs two basic operations:
#
# 1. **FIND**: Determines to which subset (tree) an element (vertex in the graph) belongs.
# 1. **UNION**: Performs the union of two subsets.
#
# **INIT**: Before we can implement the `Union-Find` algorithm we will require a data structure to represent the disjoint subsets (trees).  For this purpose we will use a lookup table that enables identification of the root of the tree to which a queried vertex belongs.  This lookup table will be implemented as a dictionary, where the keys are indices of the vertices in our graph and the values are lists containing two elements, (1) the index of the 'parent' vertex and (2) the 'rank' of the tree (set).  Rank will be defined later.  The data structure enables identification of the root of a tree to which a vertex belongs through traversal of 'parent' links until the root is found.
#
# **FIND**: The find operation recursively traverses the parent links to find the root of the tree, which is the vertex who is its own parent.  The index of the root vertex is returned.  In this implementation of the FIND operation it will also perform path compression as part of the traversal, in that the implementation will update the parent indices to the root index as the recursion unwinds.
#
# **UNION**: This operation uses **FIND** to determine the roots of the two trees to be merged.  If the two roots are the same no merging is necessary.  Otherwise it will *attach* the shorter tree to the taller using rank to determine which is taller.  Doing this ensures that the resulting tree is no taller than either input unless the ranks were equal in which case the the tree becomes taller by one node.  To attach one tree to another we set the parent index of the root of the shorter tree (smaller rank) to the index of the root of the taller tree (larger rank).  If the trees both have equal rank then we set the parent index of the root of the second tree to the index of the root in the first tree and increment the rank of the first tree.
#
# **Path Compression**: The idea of path compression is to *flatten* the tree when `find_set` is called.  When the find operation traverses the tree it returns the root index for that tree.  Path compression creates shortcuts that are stored in the lookup table preventing the traversal of intermediate nodes in the tree.  These shortcuts are realized by the values stored in the parent indices.
#
# **Rank**: In the description above the idea of rank and the height of a tree are used interchangeably.  So why use rank and not simply height?  The term rank is preferred in this case because of the use of path compression where the computation of height is not exact due to the skipping of levels in the tree.

# %% [markdown]
# ## Sort Weighted Edges

# %%
def sort_edges(edges):
    """
    Performs an in-place sort (non-decreasing order) of the passed edges list.
    edges - A list of tuples (i,j,w) where i and j are indices into a vertex
            array, and w is the weight of the edge connecting vertex i and 
            vertex j.
    """
    return edges.sort(key = lambda edge: edge[2])

# %% [markdown]
# ## Disjoint-set

# %%
def init_tree_lookup(vertices):
    """
    Creates a lookup table to help quickly identify to which tree the vertex
    belongs.  This is to be done be traversing the parents until the root of
    the tree is found.  This data structure also supports path compression 
    in that the 'parent' index stored for a given vertex in not required to 
    be a direct parent and may be an ancestor farther up the tree.  This
    allows 'Find' algorithms to more quickly identify vertices that belong 
    to the same tree.
    vertices - An np.array of 2D vertices to be used as the roots of the
            forest of trees.
    Returns - A dictionary whose keys are the indices of the passed 
            vertices and values are two element lists containing the index
            of the 'parent' and the rank of the tree.  
    """    
    init_tree = {}
    for i in range(len(vertices)):        
        init_tree[i] = [i, 0]
    return init_tree

# %% [markdown]
# ## Find-set

# %%
def find_set(lookup_table, v_idx):
    """
    Recursively finds the root of the tree containing v_idx, and performs path 
    compression as part of the traversal.  The lookup_table is modified such 
    that parent values for all nodes along the path from v_idx to the root are 
    updated to point to be the root index.
    lookup_table - A dict whose keys are vertex indices, e.g. v_idx, and values
            are two element lists containing the parent index and rank of the 
            tree.
    v_idx - The index of the vertex whose containing tree is to be identified.
    Returns - The index of the root of the tree containing the vertex 
            corresponding to the passed v_idx.
    """
    vertex = v_idx
    path = []
    while(lookup_table[vertex][0] != vertex):
        path.append(vertex)
        vertex = lookup_table[vertex][0]
    #Path compression
    for elements in path:
        lookup_table[elements][0] = vertex
    
    return vertex

# %% [markdown]
# ## Union

# %%
def union(lookup_table, u_idx, v_idx):
    """
    Merges the trees containing the vertices identified by u_idx and v_idx.
    This operation uses find_set to determine the roots of the two trees to be 
    merged.  If the two roots are the same no merging is necessary and the 
    function returns.  If the rank of the u_idx tree is greater than the rank 
    of the v_idx tree then the v_idx tree root is updated to be the root of the 
    u_idx tree, and vice versa.  If the ranks are equal then the root of the 
    v_idx tree is set to the root of the u_idx tree and the rank of the u_idx
    tree is incremented by one.
    lookup_table - A dict whose keys are vertex indices, e.g. v_idx, and values
            are two element lists containing the parent index and rank of the 
            tree.
    u_idx - The index of the vertex whose containing tree is to be merged with
            the tree of v_idx.
    v_idx - The index of the vertex whose containing tree is to be merged with 
            the tree of u_idx.
    """
    u_idx_root = find_set(lookup_table, u_idx)
    v_idx_root = find_set(lookup_table, v_idx)
    if u_idx_root == v_idx_root:
        return
    if lookup_table[u_idx_root][1] > lookup_table[v_idx_root][1]:
        #This is faster than path compression since it avoids loop and additional storage
        lookup_table[v_idx][0] = lookup_table[u_idx][0]
        lookup_table[v_idx_root][0] = lookup_table[u_idx_root][0]
    elif lookup_table[u_idx_root][1] < lookup_table[v_idx_root][1]:
        lookup_table[u_idx][0] = lookup_table[v_idx][0]
        lookup_table[u_idx_root][0] = lookup_table[v_idx_root][0]
    else:
        lookup_table[v_idx][0] = lookup_table[u_idx][0]
        lookup_table[v_idx_root][0] = lookup_table[u_idx_root][0]
        lookup_table[u_idx][1] +=1
    return

# %% [markdown]
# ## Kruskal's Algorithm

# %%
def find_MST_Kruskal(vertices, edges):
    """
    Uses Kruskal's algorithm with path compression to find and return the
    minimum spanning tree, MST, of the passed graph (vertices, edges).
    vertices - An np.array containing the 2D vertices of the graph.
    edges - A list of edge tuples (i,j,w) where i and j are indices into 
            vertices, and w is the weight of the edge connecting the 
            vertices, vertices[i] and vertices[j]. 
    Returns - mst_edges, root_idx, where mst_edges is a list of edge 
            tuples (i,j,w) copied from the input edges, and root_idx is
            the index of the root of the MST.
    """    
    tree = init_tree_lookup(vertices)
    sorted_edges = sort_edges(edges)
    edges_in_MST = []
    i=0
    while(len(edges_in_MST)<len(vertices)-1):
        if find_set(tree,sorted_edges[i][0]) == find_set(tree,sorted_edges[i][1]):
            i+=1
            continue
        else:            
            union(tree, sorted_edges[i][0],sorted_edges[i][1])
            edges_in_MST.append(sorted_edges[i])
            i+=1
    
    return (edges_in_MST,find_set(tree,sorted_edges[i-1][1]))

# %% [markdown]
# ## Test Code

# %%
# The number of vertices that the graph will contain
num_vertices = 10

# Build a random complete undirected weighted graph
vertices, edges = create_random_graph(num_vertices)

# plot the vertices - the graph is fully connected - drawing that many edges is a mess
# if you wish to see the edges change None to edges below 
plot_graph(vertices, None)

# %% [markdown]
# ## Test Code: Run Kruskal's Algorithm

# %%
mst_edges, root_idx = find_MST_Kruskal(vertices, edges)
# plot the mst edges with the vertices
plot_graph(vertices, mst_edges)

# %% [markdown]
# The following code block uses `vertices`, `mst_edges` and `root_idx` computed above to create an animation showing the order in which each edge is added to the minimum spanning tree.

# %%
last_edge_obj = None
# Create the figure
fig = plt.figure(figsize=(10, 5))
# draw the vertices
plt.scatter(vertices[:,0], vertices[:,1], marker='D',color='blue', s=25, zorder=-1)

def init():
    pass


def animate(frame_idx, vertices, edges, root_idx):
    """
    Draws the edges from index 0 to index frame_idx, along with the vertices.  
    When frame_idx exceeds the number of available edges the vertex identified
    by root_idx will be displayed in red and larger than the other vertices.
    The animation figure is closed after the root vertex is displayed.
    """
    global last_edge_obj
    
    if last_edge_obj is not None:
        # update the color on the last added edge
        last_edge_obj.set_color('gray')

    edge = edges[frame_idx] if frame_idx < len(edges) else None
    
    if edge is not None:
        # draw the new edge
        ev_x = [vertices[edge[0]][0], vertices[edge[1]][0]]
        ev_y = [vertices[edge[0]][1], vertices[edge[1]][1]]
        last_edge_obj = plt.plot(ev_x, ev_y, color='red', zorder=-2)[0]
    else:
        # draw the root node of the tree
        plt.scatter(vertices[root_idx,0], vertices[root_idx,1], marker='D',color='red', s=50)
        plt.close()
    
    
# Create the animation
ani = matplotlib.animation.FuncAnimation(fig, 
                                         animate,
                                         frames=num_vertices, 
                                         fargs=(vertices, mst_edges, root_idx),
                                         init_func=init)
# Generate HTML representation of the animation
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd682daff6ec04116a956dc99d134e6c0">
#   <div class="anim-controls">
#     <input id="_anim_sliderd682daff6ec04116a956dc99d134e6c0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd682daff6ec04116a956dc99d134e6c0.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animd682daff6ec04116a956dc99d134e6c0.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectd682daff6ec04116a956dc99d134e6c0" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d682daff6ec04116a956dc99d134e6c0"
#              >
#       <label for="_anim_radio1_d682daff6ec04116a956dc99d134e6c0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d682daff6ec04116a956dc99d134e6c0"
#              checked>
#       <label for="_anim_radio2_d682daff6ec04116a956dc99d134e6c0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d682daff6ec04116a956dc99d134e6c0"
#              >
#       <label for="_anim_radio3_d682daff6ec04116a956dc99d134e6c0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd682daff6ec04116a956dc99d134e6c0";
#     var slider_id = "_anim_sliderd682daff6ec04116a956dc99d134e6c0";
#     var loop_select_id = "_anim_loop_selectd682daff6ec04116a956dc99d134e6c0";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nO3df3BV9Z34/1fs1RIHRRFlgTjyIxQQ\
# CBm4Cp+Zll0dE37oYqlswbVbZzSlap3uitX+ZZd16qLfnWXsLF1tJrpD+wdZy2jjWMSsqB2HEem1\
# ZXYWpk7WggtBBFEqdRMgcL5/ZBPzEzw2uTc/Ho8Z5+ae8058HW+4PD05N7coSZIkAACAz+S8Qg8A\
# AACDiYAGAIAUBDQAAKQgoAEAIAUBDQAAKQhoAABIQUADAEAKAhoAAFIQ0AAAkIKABgCAFAQ0AACk\
# IKABACAFAQ0AACkIaAAASEFAAwBACgIaAABSENAAAJCCgAYAgBQENAAApCCgAQAgBQENAAApCGgA\
# AEhBQAMAQAoCGgAAUhDQAACQgoAGAIAUBDQAAKQgoAEAIAUBDQAAKQhoAABIQUADAEAKAhoAAFIQ\
# 0AAAkIKABgCAFAQ0AACkIKABAC

# %% [markdown]
# ## Preorder Traversal
#
# A preorder traversal of a binary tree visits the nodes in the following order (root, left subtree, right subtree).  The traversal is inherently recursive and when visiting any node the above ordering is simply repeated.  The following pseudocode shows a possible recursive implementation.
#
# <pre>
# Algorithm PreOrder(tree):
#   1. Visit the root
#   2. Traverse the left subtree: call PreOrder(left_subtree)
#   3. Traverse the right subtree: call PreOrder(right_subtree)
# </pre>
#
# With respect to our MST we can already see an issue in that we do not necessarily have a binary tree.  Lucky for us we can generalize the preorder traversal for trees with abitrary numbers of children at each node.  The following pseudocode implements the change.
#
# <pre>
# Algorithm PreOrder2(tree):
#   1. Visit the root
#   2. Foreach subtree in tree:
#   3.     Traverse the current subtree: call PreOrder(subtree)
# </pre>
#
# Consider the following example:
#
# ![](preorder.png)
#
# In the above tree the above algorithms return the following traversal: a b e f c d

# %% [markdown]
# ## Preorder Traversal

# %%
def tree_structure(mst_edges):
    """
    This function takes in the edges and returns a dictionary
    with vertices as keys and edges as the values
    """
    tree_nodes = {indices:[] for indices in range(len(mst_edges)+1)}
    for edges in mst_edges:
        tree_nodes[edges[0]].append(edges[1])
        tree_nodes[edges[1]].append(edges[0])
    return tree_nodes
    

def preorder(vertices, mst_edges, root_idx, visited=None, nodes = None):
    """
    Performs a preorder traversal on the MST embedded in a graph.  The 
    function returns a list containing the indices of the vertices as 
    they are encountered, only the first time they are encountered, during the
    traversal.
    vertices - An np.array containing the 2D vertices of the graph.
    mst_edges - A list of edge tuples (i,j,w) where i and j are indices
            into vertices, and w is the weight of the edge connecting  
            the vertices, vertices[i] and vertices[j]. It is assumed 
            that this list of edges make up a tree (no cycles).
    root_idx - The index of the root vertex of the tree defined by 
            mst_edges.
    visited - A boolean array used to mark which vertices have already
            beed visited.  This is used for recursive calls made by the
            function and should be set to None for the initial call, as
            the function will initialize this to an array containing 
            False for each vertex in vertices.  This helper array is 
            used because the mst_edges are undirected and come in no
            specific order.    
    Returns - A list of indices of vertices in the order they were 
            traversed.
    """
    if nodes is None:
        nodes = tree_structure(mst_edges)
    if len(nodes[root_idx])==1:
        return 
    if visited is None:
        visited = [root_idx]    
    for child in nodes[root_idx]:
        if child not in visited:
            visited.append(child)
            preorder(vertices,mst_edges,child,visited, nodes)
        else:
            continue
    return visited

# %%
''' 
def preorder_repeated(vertices, mst_edges, root_idx, visited=None,parent = None, nodes = None):    
    #The preorder traversal with all the vetices listed as they are encountered
    if nodes is None:
        nodes = tree_structure(mst_edges)    
    if visited is None:
        visited = [root_idx]   
    for child in nodes[root_idx]:
        print(root_idx,child)
        if len(nodes[child])==1:
            visited.append(child)
            visited.append(root_idx)                
        elif child != parent :
            visited.append(child)            
            preorder2(vertices,mst_edges,child,visited,root_idx, nodes)
            visited.append(root_idx)
        else:
            continue
    return visited 
'''

# %% [markdown]
# ## Test Code:

# %%
traversal = preorder(vertices, mst_edges, root_idx)

# %%
# Create the figure
fig = plt.figure(figsize=(10, 8))
# draw the MST
plt.scatter(vertices[:,0], vertices[:,1], marker='D',color='blue', s=25)
plt.scatter(vertices[root_idx,0], vertices[root_idx,1], marker='D',color='red', s=50)
for edge in mst_edges:
    ev_x = [vertices[edge[0]][0], vertices[edge[1]][0]]
    ev_y = [vertices[edge[0]][1], vertices[edge[1]][1]]
    plt.plot(ev_x, ev_y, color='black', zorder=-1)
trav_obj = plt.scatter(vertices[traversal[0],0], 
                       vertices[traversal[0],1], marker='D',color='green', s=100)
        

def init():
    pass


def animate(frame_idx, vertices, traversal):
    """
    Highlights the current position of the traversal using frame_idx, along 
    with the vertices from the graph.  
    When frame_idx exceeds the number of available steps in the traversal
    the animation figure is closed.
    """
    global trav_obj
    
    if frame_idx >= len(traversal):
        plt.close()
    else:
        # update the position in the traversal
        trav_obj.set_offsets([vertices[traversal[frame_idx],0], 
                              vertices[traversal[frame_idx],1]])
    
    
# Create the animation
ani = matplotlib.animation.FuncAnimation(fig, 
                                         animate,
                                         frames=len(traversal)+1, 
                                         fargs=(vertices, traversal),
                                         init_func=init)
# Generate HTML representation of the animation
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgafd81b1da57045149c3401ee242ba3e2">
#   <div class="anim-controls">
#     <input id="_anim_sliderafd81b1da57045149c3401ee242ba3e2" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animafd81b1da57045149c3401ee242ba3e2.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animafd81b1da57045149c3401ee242ba3e2.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectafd81b1da57045149c3401ee242ba3e2" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_afd81b1da57045149c3401ee242ba3e2"
#              >
#       <label for="_anim_radio1_afd81b1da57045149c3401ee242ba3e2">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_afd81b1da57045149c3401ee242ba3e2"
#              checked>
#       <label for="_anim_radio2_afd81b1da57045149c3401ee242ba3e2">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_afd81b1da57045149c3401ee242ba3e2"
#              >
#       <label for="_anim_radio3_afd81b1da57045149c3401ee242ba3e2">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgafd81b1da57045149c3401ee242ba3e2";
#     var slider_id = "_anim_sliderafd81b1da57045149c3401ee242ba3e2";
#     var loop_select_id = "_anim_loop_selectafd81b1da57045149c3401ee242ba3e2";
#     var frames = new Array(11);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nOzdeVjVdf7+8fsIIiiK+wIIiLhxZBkF\
# xX3hoOA02jrZ+K1+Y2a2TIs11dRM00ybTdu3qbmmGK2pybSybxfVqJH7inYsNdchFZejuOCugCzn\
# 9wfDCQTJo4fzOcvzcV1cxTkf8D5XCHdv3p/X22S32+0CAAAAcFmaGB0AAAAA8CYUaAAAAMAJFGgA\
# AADACRRoAAAAwAkUaAAAAMAJFGgAAADACRRoAAAAwAkUaAAAAMAJFGgAAADACRRoAAAAwAkUaAAA\
# AMAJFGgAAADACRRoAAAAwAkUaAAAAMAJFGgAAADACRRoAAAAwAkUaAAAAMAJFGgAAADACRRoAAAA\
# wAkUaAAAAMAJFGgAAADACRRoAAAAwAkUaAAAAMAJFGgAAADACRRoAAAAwAkUaAAAAMAJFGgAAADA\
# CRRoAAAAwAkUaAAAAMAJFGgAAA

# %% [markdown]
# ## Path Weight

# %%
def weighted_edge_dictionary(edges,traversal):
    #The reason to take traversal as an arg is because
    #number of vertices from edges will follow eqn:
    #|E| = n(n-1)/2
    #And number of vertices is same as len(traversal)
    tree_nodes = {indices:{} for indices in range(len(traversal))}
    for edges in edges:
        tree_nodes[edges[0]][edges[1]]=edges[2]
        tree_nodes[edges[1]][edges[0]]=edges[2]
    return tree_nodes
def compute_path_weight(edges, traversal):
    """
    Computes the sum of the weights of the edges in the passed traversal.
    edges - A list of edge tuples (i,j,w) where i and j are indices
            into a list of vertices, and w is the weight of the edge 
            connecting the vertices, vertices[i] and vertices[j].    
    traversal - A list of indices of vertices in the order they were 
            traversed by edges in the list edges.
    Returns - The sum of the weights along the traversal path.
    """
    path_weight = 0
    v0 = traversal[0]
    nodes = weighted_edge_dictionary(edges,traversal)
    for i in range(1,len(traversal)):
        v1 = traversal[i]
        path_weight+=nodes[v0][v1]
        v0 = v1
    return path_weight

# %% [markdown]
# ## Test Code

# %%
print('Total Path Weight for the MST is', compute_path_weight(edges, traversal))
# Out:
# Total Path Weight for the MST is 62.49668871343702

# %% [markdown]
# ## Real World Application
#
# In the following example we will attempt to apply your solutions above to a real-world problem.  Suppose you are a public health official that wants to distribute pamphlets and masks to businesses where large gatherings typically occur, and your goal for the day is to find an efficient path to all bars near campus.  Naturally your first thought is that you need to compute a Hamiltonian cycle going through each of business locations.  You second thought is that you need to visit the [College Station GIS and Map Materials webpage for Structures](https://data-cstx.opendata.arcgis.com/datasets/structures) to download information on all businesses in the area (this step has been done for you and these files can be found in the `data/Structures-shp/` folder accompanying this notebook).
#
# Run the following code block to load all businesses from the shape files according to their class and return a list of dictionaries containing all of the relevant data.

# %%
map_center = (30.625, -96.33)
bound_box = (0.015, 0.025)

location_data = load_business_locations_by_class('data/Structures-shp/Structures.shp', 

#    'FEATURE_TY': 'COMMERCIAL',
#    'JURISDICTI': 'CS',
#    'OCCUPANT': "MO'S IRISH PUB",
#    'FULL_ADDRE': '1025 UNIVERSITY DR 123',
#    'LANDMARK_C': 'BAR',
#    'CONTACT_NU': '(979) 704-3275',
#    'MF_TYPE': '',
#    'BUILDING_N': '',
#    'UNIT_LOW': '',
#    'UNIT_HIGH': '',
#    'PROJECT_NO': '',
#    'LANDUSE_TY': '',
#    'PROJECT_ST': '',
#    'created_us': 'FIRE',
#    'created_da': datetime.date(2018, 5, 21),
#    'last_edite': 'SPOTTER',
#    'last_edi_1': datetime.date(2018, 12, 13)}},
#  {'name': '1791 WHISKEY BAR',
#   'geometry': [(30.62618521820938, -96.33937104040768),
#    (30.626235983703708, -96.33931441621353),
#    (30.62616507466684, -96.3392259129635),
#    (30.626113342947317, -96.33928133308649),
#    (30.62618521820938, -96.33937104040768)],
#   'center': (30.626176967547327, -96.33931274861578),
#   'record': {'OBJECTID': 37472,
#    'FEATURE_TY': 'COMMERCIAL',
#    'JURISDICTI': 'CS',
#    'OCCUPANT': '1791 WHISKEY BAR',
#    'FULL_ADDRE': '180 CENTURY CT 108',
#    'LANDMARK_C': 'BAR',
#    'CONTACT_NU': '(979) 485-5638',
#    'MF_TYPE': '',
#    'BUILDING_N': '',
#    'UNIT_LOW': '',
#    'UNIT_HIGH': '',
#    'PROJECT_NO': '',
#    'LANDUSE_TY': '',
#    'PROJECT_ST': '',
#    'created_us': 'FIRE',
#    'created_da': datetime.date(2018, 5, 21),
#    'last_edite': 'SPOTTER',
#    'last_edi_1': datetime.date(2018, 12, 13)}},
#  {'name': 'PRIMROSE PATH WINE BAR',
#   'geometry': [(30.633901188709434, -96.32886204816147),
#    (30.634037794469403, -96.32898064758999),
#    (30.634071005477875, -96.32893120586373),
#    (30.63407093726582, -96.32891753687292),
#    (30.633970577638685, -96.32882394375075),
#    (30.63396555592306, -96.32882373846878),
#    (30.633926225061245, -96.32882620430534),
#    (30.633901188709434, -96.32886204816147)],
#   'center': (30.633980559156868, -96.3288784216468),
#   'record': {'OBJECTID': 46057,
#    'FEATURE_TY': 'COMMERCIAL',
#    'JURISDICTI': 'CS',
#    'OCCUPANT': 'PRIMROSE PATH WINE BAR',
#    'FULL_ADDRE': '701 UNIVERSITY DR E',
#    'LANDMARK_C': 'BAR',
#    'CONTACT_NU': '(979) 431-5251',
#    'MF_TYPE': '',
#    'BUILDING_N': '',
#    'UNIT_LOW': '',
#    'UNIT_HIGH': '',
#    'PROJECT_NO': '',
#    'LANDUSE_TY': 'COMMERCIAL',
#    'PROJECT_ST': '',
#    'created_us': 'NYAZDANI',
#    'created_da': datetime.date(2019, 9, 6),
#    'last_edite': 'NYAZDANI',
#    'last_edi_1': datetime.date(2019, 9, 6)}}]

# %% [markdown]
# Run the following code block to plot the above business locations, building footprints, and provides a clickable marker with the name and GPS location of the business.

# %%
plot_location_data(location_data, map_center, draw_markers=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### API Key
#
# You may optionally sign up for a free account with OpenRouteService to get an API key.  If you do so, you will be able to query the service for driving distances and the directions between them.  If you leave `api_key=None` then the naive distance between the GPS locations will be used and the last plot will not give driving directions.

# %%
# OPTIONAL
api_key = None  # Replace None with your API key string

# %% [markdown]
# Run the following code block to create a graph using the loaded location data.  The block will also use your implementation of Kruskal's algorithm to find the minimum spanning tree.

# %%
map_vertices, map_edges = create_graph_from_business_locations(location_data, api_key=api_key)

map_mst_edges, map_mst_root_idx = find_MST_Kruskal(map_vertices, map_edges)

# %% [markdown]
# Run the following code block to plot the business locations with the minimum spanning tree.  Note that this plot simply shows the tree without regard for the connecting roads.

# %%
plot_location_data(location_data, map_center, graph=(map_vertices, map_mst_edges))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mst_preoder_path = preorder(map_vertices, map_mst_edges, map_mst_root_idx)

# %% [markdown]
# Using your API key the following block will query OpenRouteService to find the driving directions along the edges of the minimum spanning tree.

# %%
directions = query_driving_directions(map_vertices, mst_preoder_path, api_key=api_key)
directions
# Out:
# {'routes': [{'summary': {'distance': 15272.8, 'duration': 2204.6},
#    'segments': [{'distance': 5.9,
#      'duration': 1.4,
#      'steps': [{'distance': 5.9,
#        'duration': 1.4,
#        'type': 11,
#        'instruction': 'Head southwest on Patricia Street',
#        'name': 'Patricia Street',
#        'way_points': [0, 1]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Patricia Street, on the left',
#        'name': '-',
#        'way_points': [1, 1]}]},
#     {'distance': 429.2,
#      'duration': 80.9,
#      'steps': [{'distance': 16.1,
#        'duration': 3.9,
#        'type': 11,
#        'instruction': 'Head southwest on Patricia Street',
#        'name': 'Patricia Street',
#        'way_points': [1, 2]},
#       {'distance': 64.1,
#        'duration': 15.4,
#        'type': 1,
#        'instruction': 'Turn right onto College Main Street',
#        'name': 'College Main Street',
#        'way_points': [2, 3]},
#       {'distance': 104.2,
#        'duration': 8.3,
#        'type': 1,
#        'instruction': 'Turn right onto Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [3, 5]},
#       {'distance': 127.0,
#        'duration': 30.5,
#        'type': 1,
#        'instruction': 'Turn right onto Tauber Street',
#        'name': 'Tauber Street',
#        'way_points': [5, 7]},
#       {'distance': 46.1,
#        'duration': 2.8,
#        'type': 1,
#        'instruction': 'Turn right onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [7, 9]},
#       {'distance': 48.0,
#        'duration': 11.5,
#        'type': 1,
#        'instruction': 'Turn right onto Lodge Street',
#        'name': 'Lodge Street',
#        'way_points': [9, 11]},
#       {'distance': 23.6,
#        'duration': 8.5,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [11, 12]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [12, 12]}]},
#     {'distance': 241.2,
#      'duration': 49.0,
#      'steps': [{'distance': 23.6,
#        'duration': 8.5,
#        'type': 11,
#        'instruction': 'Head northeast',
#        'name': '-',
#        'way_points': [12, 13]},
#       {'distance': 80.5,
#        'duration': 19.3,
#        'type': 0,
#        'instruction': 'Turn left onto Lodge Street',
#        'name': 'Lodge Street',
#        'way_points': [13, 15]},
#       {'distance': 64.1,
#        'duration': 15.4,
#        'type': 1,
#        'instruction': 'Turn right onto College Main Street',
#        'name': 'College Main Street',
#        'way_points': [15, 16]},
#       {'distance': 73.0,
#        'duration': 5.8,
#        'type': 0,
#        'instruction': 'Turn left onto Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [16, 18]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Church Avenue, on the left',
#        'name': '-',
#        'way_points': [18, 18]}]},
#     {'distance': 38.7,
#      'duration': 3.1,
#      'steps': [{'distance': 38.7,
#        'duration': 3.1,
#        'type': 11,
#        'instruction': 'Head northeast on Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [18, 20]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Church Avenue, on the right',
#        'name': '-',
#        'way_points': [20, 20]}]},
#     {'distance': 67.2,
#      'duration': 5.4,
#      'steps': [{'distance': 34.3,
#        'duration': 2.7,
#        'type': 11,
#        'instruction': 'Head northeast on Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [20, 21]},
#       {'distance': 32.9,
#        'duration': 2.6,
#        'type': 0,
#        'instruction': 'Turn left onto College Main Street',
#        'name': 'College Main Street',
#        'way_points': [21, 22]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at College Main Street, on the right',
#        'name': '-',
#        'way_points': [22, 22]}]},
#     {'distance': 123.3,
#      'duration': 24.3,
#      'steps': [{'distance': 97.0,
#        'duration': 18.0,
#        'type': 11,
#        'instruction': 'Head southeast on College Main Street',
#        'name': 'College Main Street',
#        'way_points': [22, 24]},
#       {'distance': 26.3,
#        'duration': 6.3,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [24, 25]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [25, 25]}]},
#     {'distance': 1302.5,
#      'duration': 202.9,
#      'steps': [{'distance': 26.3,
#        'duration': 6.3,
#        'type': 11,
#        'instruction': 'Head northeast',
#        'name': '-',
#        'way_points': [25, 26]},
#       {'distance': 64.1,
#        'duration': 15.4,
#        'type': 0,
#        'instruction': 'Turn left onto College Main Street',
#        'name': 'College Main Street',
#        'way_points': [26, 27]},
#       {'distance': 450.5,
#        'duration': 37.8,
#        'type': 1,
#        'instruction': 'Turn right onto Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [27, 40]},
#       {'distance': 69.5,
#        'duration': 16.7,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [40, 44]},
#       {'distance': 225.0,
#        'duration': 40.5,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [44, 46]},
#       {'distance': 110.2,
#        'duration': 22.8,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [46, 49]},
#       {'distance': 68.9,
#        'duration': 5.0,
#        'type': 1,
#        'instruction': 'Turn right onto College Avenue, TX 308',
#        'name': 'College Avenue, TX 308',
#        'way_points': [49, 50]},
#       {'distance': 126.7,
#        'duration': 22.8,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [50, 52]},
#       {'distance': 27.0,
#        'duration': 5.1,
#        'type': 1,
#        'instruction': 'Turn right onto Ball Street',
#        'name': 'Ball Street',
#        'way_points': [52, 54]},
#       {'distance': 134.4,
#        'duration': 30.6,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [54, 56]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the right',
#        'name': '-',
#        'way_points': [56, 56]}]},
#     {'distance': 385.9,
#      'duration': 79.6,
#      'steps': [{'distance': 134.4,
#        'duration': 30.6,
#        'type': 11,
#        'instruction': 'Head northwest',
#        'name': '-',
#        'way_points': [56, 58]},
#       {'distance': 251.4,
#        'duration': 48.9,
#        'type': 1,
#        'instruction': 'Turn right onto Ball Street',
#        'name': 'Ball Street',
#        'way_points': [58, 64]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Ball Street, on the right',
#        'name': '-',
#        'way_points': [64, 64]}]},
#     {'distance': 1320.9,
#      'duration': 193.9,
#      'steps': [{'distance': 72.2,
#        'duration': 13.0,
#        'type': 11,
#        'instruction': 'Head northeast',
#        'name': '-',
#        'way_points': [64, 65]},
#       {'distance': 208.1,
#        'duration': 36.2,
#        'type': 1,
#        'instruction': 'Turn right onto Century Square Drive',
#        'name': 'Century Square Drive',
#        'way_points': [65, 69]},
#       {'distance': 299.3,
#        'duration': 30.2,
#        'type': 0,
#        'instruction': 'Turn left onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [69, 72]},
#       {'distance': 414.6,
#        'duration': 44.7,
#        'type': 6,
#        'instruction': 'Continue straight onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [72, 83]},
#       {'distance': 72.1,
#        'duration': 17.3,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [83, 86]},
#       {'distance': 99.7,
#        'duration': 23.9,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [86, 90]},
#       {'distance': 10.0,
#        'duration': 2.4,
#        'type': 0,
#        'instruction': 'Turn left onto Macarthur Street',
#        'name': 'Macarthur Street',
#        'way_points': [90, 91]},
#       {'distance': 115.5,
#        'duration': 20.8,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [91, 96]},
#       {'distance': 29.3,
#        'duration': 5.3,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [96, 97]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [97, 97]}]},
#     {'distance': 963.1,
#      'duration': 120.0,
#      'steps': [{'distance': 29.3,
#        'duration': 5.3,
#        'type': 11,
#        'instruction': 'Head southeast',
#        'name': '-',
#        'way_points': [97, 98]},
#       {'distance': 115.5,
#        'duration': 20.8,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [98, 103]},
#       {'distance': 56.3,
#        'duration': 13.5,
#        'type': 0,
#        'instruction': 'Turn left onto Macarthur Street',
#        'name': 'Macarthur Street',
#        'way_points': [103, 105]},
#       {'distance': 98.6,
#        'duration': 6.5,
#        'type': 1,
#        'instruction': 'Turn right onto University Drive East, FM 60',
#        'name': 'University Drive East, FM 60',
#        'way_points': [105, 107]},
#       {'distance': 513.7,
#        'duration': 35.9,
#        'type': 6,
#        'instruction': 'Continue straight onto University Drive East, FM 60',
#        'name': 'University Drive East, FM 60',
#        'way_points': [107, 116]},
#       {'distance': 22.8,
#        'duration': 8.2,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [116, 119]},
#       {'distance': 31.3,
#        'duration': 7.5,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [119, 121]},
#       {'distance': 3.6,
#        'duration': 0.9,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [121, 122]},
#       {'distance': 82.6,
#        'duration': 19.8,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [122, 124]},
#       {'distance': 9.4,
#        'duration': 1.7,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [124, 125]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [125, 125]}]},
#     {'distance': 401.2,
#      'duration': 42.7,
#      'steps': [{'distance': 27.0,
#        'duration': 4.9,
#        'type': 11,
#        'instruction': 'Head northeast',
#        'name': '-',
#        'way_points': [125, 126]},
#       {'distance': 77.1,
#        'duration': 13.9,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [126, 130]},
#       {'distance': 101.2,
#        'duration': 6.1,
#        'type': 1,
#        'instruction': 'Turn right onto University Drive East, FM 60',
#        'name': 'University Drive East, FM 60',
#        'way_points': [130, 133]},
#       {'distance': 195.8,
#        'duration': 17.9,
#        'type': 6,
#        'instruction': 'Continue straight onto University Drive East, FM 60',
#        'name': 'University Drive East, FM 60',
#        'way_points': [133, 137]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at University Drive East, FM 60, on the left',
#        'name': '-',
#        'way_points': [137, 137]}]},
#     {'distance': 2451.7,
#      'duration': 488.6,
#      'steps': [{'distance': 81.1,
#        'duration': 5.3,
#        'type': 11,
#        'instruction': 'Head southwest on University Drive East, FM 60',
#        'name': 'University Drive East, FM 60',
#        'way_points': [137, 140]},
#       {'distance': 203.9,
#        'duration': 21.2,
#        'type': 0,
#        'instruction': 'Turn left onto Tarrow Street',
#        'name': 'Tarrow Street',
#        'way_points': [140, 145]},
#       {'distance': 127.8,
#        'duration': 30.7,
#        'type': 1,
#        'instruction': 'Turn right onto Banks Street',
#        'name': 'Banks Street',
#        'way_points': [145, 147]},
#       {'distance': 190.0,
#        'duration': 45.6,
#        'type': 0,
#        'instruction': 'Turn left onto Churchill Street',
#        'name': 'Churchill Street',
#        'way_points': [147, 152]},
#       {'distance': 13.5,
#        'duration': 3.2,
#        'type': 1,
#        'instruction': 'Turn right onto Preston Street',
#        'name': 'Preston Street',
#        'way_points': [152, 153]},
#       {'distance': 152.0,
#        'duration': 18.2,
#        'type': 0,
#        'instruction': 'Turn left onto Churchill Street',
#        'name': 'Churchill Street',
#        'way_points': [153, 154]},
#       {'distance': 128.6,
#        'duration': 9.3,
#        'type': 1,
#        'instruction': 'Turn right onto Lincoln Avenue',
#        'name': 'Lincoln Avenue',
#        'way_points': [154, 156]},
#       {'distance': 84.8,
#        'duration': 20.4,
#        'type': 0,
#        'instruction': 'Turn left onto Nunn Street',
#        'name': 'Nunn Street',
#        'way_points': [156, 160]},
#       {'distance': 57.7,
#        'duration': 13.8,
#        'type': 1,
#        'instruction': 'Turn right onto Walton Drive',
#        'name': 'Walton Drive',
#        'way_points': [160, 162]},
#       {'distance': 1039.7,
#        'duration': 249.5,
#        'type': 0,
#        'instruction': 'Turn left onto Puryear Drive',
#        'name': 'Puryear Drive',
#        'way_points': [162, 192]},
#       {'distance': 257.6,
#        'duration': 50.7,
#        'type': 1,
#        'instruction': 'Turn right onto Dominik Drive',
#        'name': 'Dominik Drive',
#        'way_points': [192, 197]},
#       {'distance': 114.9,
#        'duration': 20.7,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [197, 199]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the right',
#        'name': '-',
#        'way_points': [199, 199]}]},
#     {'distance': 1253.1,
#      'duration': 137.2,
#      'steps': [{'distance': 350.4,
#        'duration': 63.1,
#        'type': 11,
#        'instruction': 'Head southeast',
#        'name': '-',
#        'way_points': [199, 213]},
#       {'distance': 49.5,
#        'duration': 4.0,
#        'type': 0,
#        'instruction': 'Turn left onto Harvey Road, TX 30',
#        'name': 'Harvey Road, TX 30',
#        'way_points': [213, 215]},
#       {'distance': 774.0,
#        'duration': 55.9,
#        'type': 5,
#        'instruction': 'Turn slight right onto Harvey Road, TX 30',
#        'name': 'Harvey Road, TX 30',
#        'way_points': [215, 235]},
#       {'distance': 79.3,
#        'duration': 14.3,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [235, 238]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [238, 238]}]},
#     {'distance': 4490.5,
#      'duration': 555.6,
#      'steps': [{'distance': 68.5,
#        'duration': 12.3,
#        'type': 11,
#        'instruction': 'Head northwest',
#        'name': '-',
#        'way_points': [238, 240]},
#       {'distance': 147.6,
#        'duration': 29.9,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [240, 242]},
#       {'distance': 669.0,
#        'duration': 48.2,
#        'type': 0,
#        'instruction': 'Turn left onto University Oaks Boulevard',
#        'name': 'University Oaks Boulevard',
#        'way_points': [242, 255]},
#       {'distance': 418.6,
#        'duration': 48.1,
#        'type': 1,
#        'instruction': 'Turn right onto George Bush Drive East',
#        'name': 'George Bush Drive East',
#        'way_points': [255, 271]},
#       {'distance': 212.0,
#        'duration': 50.9,
#        'type': 1,
#        'instruction': 'Turn right onto Foster Avenue',
#        'name': 'Foster Avenue',
#        'way_points': [271, 282]},
#       {'distance': 136.8,
#        'duration': 32.8,
#        'type': 0,
#        'instruction': 'Turn left onto Gilchrist Avenue',
#        'name': 'Gilchrist Avenue',
#        'way_points': [282, 285]},
#       {'distance': 609.1,
#        'duration': 36.5,
#        'type': 1,
#        'instruction': 'Turn right onto Texas Avenue, TX 6 BUS',
#        'name': 'Texas Avenue, TX 6 BUS',
#        'way_points': [285, 293]},
#       {'distance': 627.5,
#        'duration': 79.4,
#        'type': 0,
#        'instruction': 'Turn left onto New Main Drive',
#        'name': 'New Main Drive',
#        'way_points': [293, 299]},
#       {'distance': 310.2,
#        'duration': 41.5,
#        'type': 13,
#        'instruction': 'Keep right',
#        'name': '-',
#        'way_points': [299, 315]},
#       {'distance': 591.5,
#        'duration': 76.9,
#        'type': 6,
#        'instruction': 'Continue straight onto Ross Street',
#        'name': 'Ross Street',
#        'way_points': [315, 332]},
#       {'distance': 459.0,
#        'duration': 72.2,
#        'type': 1,
#        'instruction': 'Turn right onto Asbury Street',
#        'name': 'Asbury Street',
#        'way_points': [332, 343]},
#       {'distance': 192.2,
#        'duration': 15.4,
#        'type': 0,
#        'instruction': 'Turn left onto Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [343, 347]},
#       {'distance': 48.4,
#        'duration': 11.6,
#        'type': 0,
#        'instruction': 'Turn left',
#        'name': '-',
#        'way_points': [347, 352]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at your destination, on the left',
#        'name': '-',
#        'way_points': [352, 352]}]},
#     {'distance': 133.4,
#      'duration': 27.6,
#      'steps': [{'distance': 96.9,
#        'duration': 23.3,
#        'type': 11,
#        'instruction': 'Head southwest',
#        'name': '-',
#        'way_points': [352, 353]},
#       {'distance': 36.5,
#        'duration': 4.4,
#        'type': 0,
#        'instruction': 'Turn left onto Boyett Street',
#        'name': 'Boyett Street',
#        'way_points': [353, 356]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Boyett Street, on the left',
#        'name': '-',
#        'way_points': [356, 356]}]},
#     {'distance': 74.6,
#      'duration': 15.3,
#      'steps': [{'distance': 22.0,
#        'duration': 2.6,
#        'type': 11,
#        'instruction': 'Head northwest on Boyett Street',
#        'name': 'Boyett Street',
#        'way_points': [356, 358]},
#       {'distance': 52.7,
#        'duration': 12.6,
#        'type': 1,
#        'instruction': 'Turn right onto Patricia Street',
#        'name': 'Patricia Street',
#        'way_points': [358, 360]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Patricia Street, on the right',
#        'name': '-',
#        'way_points': [360, 360]}]},
#     {'distance': 167.0,
#      'duration': 23.5,
#      'steps': [{'distance': 52.7,
#        'duration': 12.6,
#        'type': 11,
#        'instruction': 'Head southwest on Patricia Street',
#        'name': 'Patricia Street',
#        'way_points': [360, 362]},
#       {'distance': 62.2,
#        'duration': 7.5,
#        'type': 0,
#        'instruction': 'Turn left onto Boyett Street',
#        'name': 'Boyett Street',
#        'way_points': [362, 365]},
#       {'distance': 52.2,
#        'duration': 3.4,
#        'type': 1,
#        'instruction': 'Turn right onto Raymond Stotzer Parkway, FM 60',
#        'name': 'Raymond Stotzer Parkway, FM 60',
#        'way_points': [365, 366]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Raymond Stotzer Parkway, FM 60, on the right',
#        'name': '-',
#        'way_points': [366, 366]}]},
#     {'distance': 241.5,
#      'duration': 44.6,
#      'steps': [{'distance': 41.2,
#        'duration': 2.7,
#        'type': 11,
#        'instruction': 'Head southwest on Raymond Stotzer Parkway, FM 60',
#        'name': 'Raymond Stotzer Parkway, FM 60',
#        'way_points': [366, 368]},
#       {'distance': 127.7,
#        'duration': 33.2,
#        'type': 1,
#        'instruction': 'Turn right',
#        'name': '-',
#        'way_points': [368, 372]},
#       {'distance': 72.7,
#        'duration': 8.7,
#        'type': 1,
#        'instruction': 'Turn right onto Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [372, 373]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Church Avenue, on the right',
#        'name': '-',
#        'way_points': [373, 373]}]},
#     {'distance': 588.3,
#      'duration': 66.0,
#      'steps': [{'distance': 318.7,
#        'duration': 26.7,
#        'type': 11,
#        'instruction': 'Head northeast on Church Avenue',
#        'name': 'Church Avenue',
#        'way_points': [373, 379]},
#       {'distance': 127.0,
#        'duration': 30.5,
#        'type': 1,
#        'instruction': 'Turn right onto Tauber Street',
#        'name': 'Tauber Street',
#        'way_points': [379, 381]},
#       {'distance': 142.6,
#        'duration': 8.8,
#        'type': 1,
#        'instruction': 'Turn right onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [381, 386]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at University Drive, FM 60, on the right',
#        'name': '-',
#        'way_points': [386, 386]}]},
#     {'distance': 37.3,
#      'duration': 2.4,
#      'steps': [{'distance': 37.3,
#        'duration': 2.4,
#        'type': 11,
#        'instruction': 'Head southwest on Raymond Stotzer Parkway, FM 60',
#        'name': 'Raymond Stotzer Parkway, FM 60',
#        'way_points': [386, 387]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at Raymond Stotzer Parkway, FM 60, on the right',
#        'name': '-',
#        'way_points': [387, 387]}]},
#     {'distance': 556.3,
#      'duration': 40.6,
#      'steps': [{'distance': 123.2,
#        'duration': 8.1,
#        'type': 11,
#        'instruction': 'Head southwest on Raymond Stotzer Parkway, FM 60',
#        'name': 'Raymond Stotzer Parkway, FM 60',
#        'way_points': [387, 389]},
#       {'distance': 13.8,
#        'duration': 1.7,
#        'type': 0,
#        'instruction': 'Turn left onto Boyett Street',
#        'name': 'Boyett Street',
#        'way_points': [389, 390]},
#       {'distance': 308.3,
#        'duration': 21.4,
#        'type': 0,
#        'instruction': 'Turn left onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [390, 395]},
#       {'distance': 111.0,
#        'duration': 9.5,
#        'type': 6,
#        'instruction': 'Continue straight onto University Drive, FM 60',
#        'name': 'University Drive, FM 60',
#        'way_points': [395, 400]},
#       {'distance': 0.0,
#        'duration': 0.0,
#        'type': 10,
#        'instruction': 'Arrive at University Drive, FM 60, on the right',
#        'name': '-',
#        'way_points': [400, 400]}]}],
#    'bbox': [-96.348501, 30.616079, -96.311762, 30.634542],
#    'geometry': 'eg{yDjp`kQFFRVuAvAoAuAy@}@JYlCgDHHp@t@GJs@z@^`@_@a@ORtA`BuAvAhArARTSU]a@k@q@k@l@j@m@tAwA^f@_@g@uAvAoAuAy@}@y@aA{@cAeBsBk@o@KWOi@KQg@m@i@o@IIWg@k@T[HU@Y?uDjEkByBh@u@kAqASYtAgBUWoC{CZa@EEbCcD`@i@a@h@cCbDoAuA]a@gAqAc@e@sAwA[_@}AeB@CdCkD|AmBX_@iE{E_BeBaBgBg@k@CCKMQUQSoAoAcAaA_@a@gCuCCAgCuCOTg@p@_@d@s@}@Sa@CSe@i@KNOQYYKMSSoAsAc@j@b@k@nArARRJLXXNPJOv@eADBzBfCNU_CiCwA_BcAkAwBeCs@y@wBgCW[m@y@@OBGNOMOUa@BC]a@hAyAKMa@g@w@|@[d@A@KLa@{@c@gAWq@YP^bAz@lBxA~B?@bAzA\\^RYHKfB}B\\c@vAkBtAzAnAzAp@y@`@i@VYT[lBaCPRzDgFvBbCn@r@R[\\}@PSZYT^p@v@`DkFxDmFdAiBb@m@V[ZWFEdAu@RIh@IpAMp@Gz@Kd@GTITUVk@Tm@FWNYn@s@T]J[Li@Jg@Nc@N[R[NQhC_DbAj@^XTVlEdFTVV]pBuCrAmBX_@T[T[Xa@V]Va@V]T]j@y@TYV_@b@q@RWi@k@]Ic@g@EEwAcBc@k@MOkC{Ca@e@KOOOc@i@_BkBs@}@_BkBGIa@g@kAsAyAiBk@s@k@o@c@i@[^m@n@]`@}@dAY]cArAsBhCrBbC`CpCTTx@bAtA`Bd@h@bAlAn@t@hBxBRRhBxBp@x@LLuAlB[b@_BxBQNQJGBe@j@S^Ur@E`@AXFbAJb@N\\PXb@b@ELMVCRAPTpBB^A\\EVK\\MVw@bAxA|ApAtAJJ_DnEyChEqAfBeAxAUZ{EvGILQPTXHLtBpDlErHzDnGzCfFJVBL?NCLGJk@~@a@hASjAE|@AP?LFhAJx@HZFTLXJR\\n@\\`@TNT\\nB`DFHHNXd@hAhB~AlCh@x@fBrCLR\\j@`@n@FJKJ}@x@kC~BiA`Aw@t@GFoAjAKHM\\mCfDKXx@|@nAtAhArAf@j@RUDENUDGNEbCdCRSRUHGIFST_@e@c@g@b@f@^d@RU`@c@\\[`AhAPR`@j@GTEPaAfAoAhA}AiBg@k@{BiCg@k@iAsAoAuAy@}@JYlCgDHHp@t@`AdA^b@\\^n@t@BB|ClDPSaDkDmAwA]e@uBaCMOM\\HHp@t@`AdA??',
#    'way_points': [0,
#     1,
#     12,
#     18,
#     20,
#     22,
#     25,
#     56,
#     64,
#     97,
#     125,
#     137,
#     199,
#     238,
#     352,
#     356,
#     360,
#     366,
#     373,
#     386,
#     387,
#     400]}],
#  'bbox': [-96.348501, 30.616079, -96.311762, 30.634542],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'routing',
#   'timestamp': 1603990773814,
#   'query': {'coordinates': [[-96.34577223128656, 30.618870844921826],
#     [-96.34576703594325, 30.61879302841968],
#     [-96.34565351363186, 30.618814789169715],
#     [-96.34706494319985, 30.618820462713813],
#     [-96.34678046812184, 30.619067465331206],
#     [-96.34685159587876, 30.61926969897128],
#     [-96.34628594364949, 30.618705380850134],
#     [-96.34001175300534, 30.623918647301775],
#     [-96.33931274861578, 30.626176967547327],
#     [-96.33164884902978, 30.632036877598935],
#     [-96.32731526472466, 30.63315944188675],
#     [-96.3288784216468, 30.633980559156868],
#     [-96.32020532146538, 30.61839821422213],
#     [-96.31216406254012, 30.62206715049929],
#     [-96.34645246414145, 30.61816285797683],
#     [-96.34733184844328, 30.61726753993331],
#     [-96.34653882015876, 30.61792131970911],
#     [-96.34751663124528, 30.617013583576302],
#     [-96.3481643894987, 30.61796552689872],
#     [-96.34588853442625, 30.618318359039232],
#     [-96.34621451284873, 30.618122712652923],
#     [-96.34557192851472, 30.618643463772077]],
#    'profile': 'driving-car',
#    'preference': 'shortest',
#    'format': 'json'},
#   'engine': {'version': '6.3.0',
#    'build_date': '2020-09-21T01:00:26Z',
#    'graph_date': '1970-01-01T00:00:00Z'}}}

# %% [markdown]
# Run the following code block to plot the business locations along with any driving directions found in the previous block.

# %%
plot_location_data(location_data, map_center, directions=directions)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
